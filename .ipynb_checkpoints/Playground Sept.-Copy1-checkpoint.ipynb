# %% [markdown]
# <h1 style='background-image: url("data:image/jpeg;base64,...");color: #008000;font-weight: bolder'>𝒦𝒶𝑔𝑔𝓁𝑒 𝒮𝑒𝓅𝓉𝑒𝓂𝒷𝑒𝓇 𝒯𝒶𝒷𝓊𝓁𝒶𝓇 𝒫𝓁𝒶𝓎𝑔𝓇𝑜𝓊𝓃𝒹</h1>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"\Users\Slmss\Desktop\Tabular\train.csv")
data.head()
# Out:
#    row_id        date  country       store                           product  \
# 0       0  2017-01-01  Belgium  KaggleMart        Kaggle Advanced Techniques
# 1       1  2017-01-01  Belgium  KaggleMart            Kaggle Getting Started
# 2       2  2017-01-01  Belgium  KaggleMart                Kaggle Recipe Book
# 3       3  2017-01-01  Belgium  KaggleMart  Kaggle for Kids: One Smart Goose
# 4       4  2017-01-01  Belgium  KaggleRama        Kaggle Advanced Techniques
#
#    num_sold
# 0       663
# 1       615
# 2       480
# 3       710
# 4       240

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data.num_sold)
plt.show()

# %%
pd.DataFrame(data['store'].value_counts()).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 data.plot(kind='bar')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:329, in MPLPlot.generate(self)
#     327 self._compute_plot_data()
#     328 self._setup_subplots()
# --> 329 self._make_plot()
#     330 self._add_table()
#     331 self._make_legend()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1558, in BarPlot._make_plot(self)
#    1556 else:
#    1557     w = self.bar_width / K
# -> 1558     rect = self._plot(
#    1559         ax,
#    1560         self.ax_pos + (i + 0.5) * w,
#    1561         y,
#    1562         w,
#    1563         start=start,
#    1564         label=label,
#    1565         log=self.log,
#    1566         **kwds,
#    1567     )
#    1568 self._append_legend_handles_labels(rect, label)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1488, in BarPlot._plot(cls, ax, x, y, w, start, log, **kwds)
#    1484 @classmethod
#    1485 def _plot(  # type: ignore[override]
#    1486     cls, ax: Axes, x, y, w, start=0, log=False, **kwds
#    1487 ):
# -> 1488     return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:2409, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2407     elif orientation == 'horizontal':
#    2408         r.sticky_edges.x.append(l)
# -> 2409     self.add_patch(r)
#    2410     patches.append(r)
#    2412 if xerr is not None or yerr is not None:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2362, in _AxesBase.add_patch(self, p)
#    2360 self._set_artist_props(p)
#    2361 if p.get_clip_path() is None:
# -> 2362     p.set_clip_path(self.patch)
#    2363 self._update_patch_limits(p)
#    2364 self._children.append(p)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:790, in Artist.set_clip_path(self, path, transform)
#     787 if transform is None:
#     788     if isinstance(path, Rectangle):
#     789         self.clipbox = TransformedBbox(Bbox.unit(),
# --> 790                                        path.get_transform())
#     791         self._clippath = None
#     792         success = True
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py:278, in Patch.get_transform(self)
#     276 def get_transform(self):
#     277     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 278     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py:760, in Rectangle.get_patch_transform(self)
#     753 def get_patch_transform(self):
#     754     # Note: This cannot be called until after this has been added to
#     755     # an Axes, otherwise unit conversion will fail. This makes it very
#     756     # important to call the accessor method and not directly access the
#     757     # transformation member variable.
#     758     bbox = self.get_bbox()
#     759     return (transforms.BboxTransformTo(bbox)
# --> 760             + transforms.Affine2D().rotate_deg_around(
#     761                 bbox.x0, bbox.y0, self.angle))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py:2042, in Affine2D.rotate_deg_around(self, x, y, degrees)
#    2040 # Cast to float to avoid wraparound issues with uint8's
#    2041 x, y = float(x), float(y)
# -> 2042 return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py:2020, in Affine2D.rotate_deg(self, degrees)
#    2012 def rotate_deg(self, degrees):
#    2013     """
#    2014     Add a rotation (in degrees) to this transform in place.
#    2015
#    (...)
#    2018     and :meth:`scale`.
#    2019     """
# -> 2020     return self.rotate(math.radians(degrees))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py:2008, in Affine2D.rotate(self, theta)
#    2005 b = math.sin(theta)
#    2006 rotate_mtx = np.array([[a, -b, 0.0], [b, a, 0.0], [0.0, 0.0, 1.0]],
#    2007                       float)
# -> 2008 self._mtx = np.dot(rotate_mtx, self._mtx)
#    2009 self.invalidate()
#    2010 return self
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x00000268A503F0D0> (for post_execute):
# KeyboardInterrupt

# %%
pd.DataFrame(data['product'].value_counts()).plot(kind='bar',stacked=True)
plt.show()

# %%
pd.DatetimeIndex(data.date)[0]-pd.DatetimeIndex(data.date)[-1]
# Out:
# Timedelta('-1460 days +00:00:00')

# %%
df=data.set_index(pd.DatetimeIndex(data.date)).drop('date',axis=1)
df
# Out:
#             row_id  country       store                           product  \
# date
# 2017-01-01       0  Belgium  KaggleMart        Kaggle Advanced Techniques
# 2017-01-01       1  Belgium  KaggleMart            Kaggle Getting Started
# 2020-12-31                                         1
# 2020-12-31                                         0
# 2020-12-31                                         0
# 2020-12-31                                         0
# 2020-12-31                                         1
#
# [70128 rows x 14 columns]

# %%
X=df2.drop('num_sold',axis=1).values
Y=df2['num_sold'].values
X=X.reshape(70128, 13,1)
Y=Y.reshape(70128)

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense,RNN,Bidirectional

nn=Sequential()
nn.add(LSTM(5,activation='relu',input_shape=(13,1),return_sequences=True))

for i in range(10):
    nn.add(LSTM(5,activation='relu',return_sequences=True))

nn.add(LSTM(5,activation='relu'))

nn.add(Dense(1))
nn.compile(loss='mse',optimizer='adam')
nn.fit(X,Y,epochs=100)
# Out:
# Epoch 1/100
# 2192/2192 [==============================] - 306s 91ms/step - loss: 18021.2168
# Epoch 2/100
# 2192/2192 [==============================] - 200s 91ms/step - loss: 16207.9268
# Epoch 3/100
# 2192/2192 [==============================] - 197s 90ms/step - loss: 16168.9326
# Epoch 4/100
# 2192/2192 [==============================] - 189s 86ms/step - loss: 16884.5918
# Epoch 5/100
# 2192/2192 [==============================] - 198s 91ms/step - loss: 16126.8193
# Epoch 6/100
# 2192/2192 [==============================] - 200s 91ms/step - loss: 16150.5654
# Epoch 7/100
# 2192/2192 [==============================] - 203s 93ms/step - loss: 16172.2695
# Epoch 8/100
# 2192/2192 [==============================] - 199s 91ms/step - loss: 16137.6738
# Epoch 9/100
# 2192/2192 [==============================] - 198s 90ms/step - loss: 16010.4883
# Epoch 10/100
# 2192/2192 [==============================] - 220s 100ms/step - loss: 16011.7012
# Epoch 11/100
# 2192/2192 [==============================] - 217s 99ms/step - loss: 15971.4189
# Epoch 12/100
# 2192/2192 [==============================] - 205s 93ms/step - loss: 15956.0010
# Epoch 13/100
# 2192/2192 [==============================] - 212s 97ms/step - loss: 16062.2373
# Epoch 14/100
# 2192/2192 [==============================] - 203s 93ms/step - loss: 15990.0674
# Epoch 15/100
# 2192/2192 [==============================] - 211s 96ms/step - loss: 15963.1504
# Epoch 16/100
# 2192/2192 [==============================] - 210s 96ms/step - loss: 18024.4590
# Epoch 17/100
# 2192/2192 [==============================] - 203s 93ms/step - loss: 15879.5068
# Epoch 18/100
# 2192/2192 [==============================] - 206s 94ms/step - loss: 15893.7021
# Epoch 19/100
# 2192/2192 [==============================] - 202s 92ms/step - loss: 15968.7041
# Epoch 20/100
# 2192/2192 [==============================] - 206s 94ms/step - loss: 15984.3652
# Epoch 21/100
# 2192/2192 [==============================] - 206s 94ms/step - loss: 15945.0352
# Epoch 22/100
# 2192/2192 [==============================] - 214s 98ms/step - loss: 15958.9053
# Epoch 23/100
# 2192/2192 [==============================] - 211s 96ms/step - loss: 15955.9424
# Epoch 24/100
# 2192/2192 [==============================] - 205s 94ms/step - loss: 15981.4902
# Epoch 25/100
# 2192/2192 [==============================] - 206s 94ms/step - loss: 15964.2051
# Epoch 26/100
# 2192/2192 [==============================] - 204s 93ms/step - loss: 15985.4551
# Epoch 27/100
# 2192/2192 [==============================] - 204s 93ms/step - loss: 15956.7783
# Epoch 28/100
# 2192/2192 [==============================] - 204s 93ms/step - loss: 15946.7285
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
# ----> 1 nn.fit(X,Y,epochs=1000)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
data.country.value_counts()
# Out:
# Belgium    11688
# France     11688
# Germany    11688
# Italy      11688
# Poland     11688
# Spain      11688
# Name: country, dtype: int64

# %%
data.store.value_counts()
# Out:
# KaggleMart    35064
# KaggleRama    35064
# Name: store, dtype: int64

# %%
data.product()

# %%
data.tail()
# Out:
#        row_id        date country       store  \
# 70123   70123  2020-12-31   Spain  KaggleMart
# 70124   70124  2020-12-31   Spain  KaggleRama
# 70125   70125  2020-12-31   Spain  KaggleRama
# 70126   70126  2020-12-31   Spain  KaggleRama
# 70127   70127  2020-12-31   Spain  KaggleRama
#
#                                 product  num_sold
# 70123  Kaggle for Kids: One Smart Goose       614
# 70124        Kaggle Advanced Techniques       215
# 70125            Kaggle Getting Started       158
# 70126                Kaggle Recipe Book       135
# 70127  Kaggle for Kids: One Smart Goose       202

# %%
data.shape
# Out:
# (70128, 6)

# %%
data.describe()
# Out:
#              row_id      num_sold
# count  70128.000000  70128.000000
# mean   35063.500000    194.296986
# std    20244.354176    126.893874
# min        0.000000     19.000000
# 25%    17531.750000     95.000000
# 50%    35063.500000    148.000000
# 75%    52595.250000    283.000000
# max    70127.000000    986.000000

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(data[['row_id','num_sold']])
scl=pd.DataFrame(sc.transform(data[['row_id','num_sold']]),columns=['row_id','num_sold'])

# %%
scl
# Out:
#          row_id  num_sold
# 0     -1.732026  3.693688
# 1     -1.731977  3.315416
# 2     -1.731927  2.251528
# 3     -1.731878  4.064079
# 4     -1.731829  0.360170
# ...         ...       ...
# 70123  1.731829  3.307536
# 70124  1.731878  0.163153
# 70125  1.731927 -0.286044
# 70126  1.731977 -0.467299
# 70127  1.732026  0.060705
#
# [70128 rows x 2 columns]

# %%
import statsmodels.formula.api as smf
model = smf.ols("num_sold~row_id",data = scl).fit()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
model.params
# Out:
# Intercept   -2.019218e-15
# row_id       9.796847e-02
# dtype: float64

# %%
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept   -5.373002e-13
# row_id       2.606874e+01
# dtype: float64
#  Intercept     1.000000e+00
# row_id       4.255404e-149
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.009597822058601824, 0.009583698877785318)

# %%
y=pd.read_csv(r'\Users\Slmss\Desktop\Tabular\test.csv')

# %%
sc=StandardScaler()
sc.fit(y[['row_id']])
scl=pd.DataFrame(sc.transform(y[['row_id']]),columns=['row_id'])

# %%
df=pd.DataFrame(model.predict(scl['row_id']),columns=['num_sold'])

# %%
sc.inverse_transform(fdf)
# Out:
# array([[1.41972101e+09, 1.72766206e+02],
#        [1.41974126e+09, 1.72768664e+02],
#        [1.41976150e+09, 1.72771122e+02],
#        ...,
#        [1.77433883e+09, 2.15822849e+02],
#        [1.77435908e+09, 2.15825307e+02],
#        [1.77437932e+09, 2.15827765e+02]])

# %%
fdf=pd.concat((y[['row_id']],df),axis=1,join='inner')
fdf.to_csv(r'\Users\Slmss\Desktop\Tabular\Submission.csv',index=False)

# %%
dir(sc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_feature_names',
#  '_check_n_features',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_reset',
#  '_validate_data',
#  'copy',
#  'feature_names_in_',
#  'fit',
#  'fit_transform',
#  'get_feature_names_out',
#  'get_params',
#  'inverse_transform',
#  'mean_',
#  'n_features_in_',
#  'n_samples_seen_',
#  'partial_fit',
#  'scale_',
#  'set_params',
#  'transform',
#  'var_',
#  'with_mean',
#  'with_std']

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense,RNN,Bidirectional

# %%
data.shape
# Out:
# (70128, 6)

# %%
X=data[['row_id']].values
Y=data[['num_sold']].values
X=X.reshape(70128,1,1)
Y=Y.reshape(70128)

# %%
Y.shape,X.shape
# Out:
# ((70128,), (1, 70128, 1))

# %%
X,Y
# Out:
# (array([[[    0],
#          [    1],
#          [    2],
#          ...,
#          [70125],
#          [70126],
#          [70127]]], dtype=int64),
#  array([663, 615, 480, ..., 158, 135, 202], dtype=int64))

# %%
nn=Sequential()
nn.add(LSTM(500,activation='relu',input_shape=(1,1),return_sequences=True))

for i in range(10):
    nn.add(LSTM(500,activation='relu',return_sequences=True))

nn.add(LSTM(50,activation='relu'))
# Out:
# Epoch 1/100
# 2192/2192 [==============================] - 134s 59ms/step - loss: 555743.0625
# Epoch 2/100
# 2192/2192 [==============================] - 107s 49ms/step - loss: 126990.1172
# Epoch 3/100
# 2192/2192 [==============================] - 106s 48ms/step - loss: 23666.9707
# Epoch 4/100
# 1452/2192 [==================>...........] - ETA: 35s - loss: 23766.3965

# %%
nn.add(Dense(1))
nn.compile(loss='mse',optimizer='adam')
nn.fit(X,Y,epochs=100)

# %%
nn.fit(X,Y,epochs=10000)

# %%
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 1, 50)             10400
#
#  lstm_6 (LSTM)               (None, 1, 50)             20200
#
#  lstm_7 (LSTM)               (None, 50)                20200
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
import xgbm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 import xgbm
#
# ModuleNotFoundError: No module named 'xgbm'

# %%
# Out:
# Epoch 1/100
# 2192/2192 [==============================] - 9s 3ms/step - loss: 34067.0391
# Epoch 2/100
# 2192/2192 [==============================] - 7s 3ms/step - loss: 23447.0703
# Epoch 3/100
# 2192/2192 [==============================] - 7s 3ms/step - loss: 730615.5625
# Epoch 4/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 2011103.7500
# Epoch 5/100
# 2192/2192 [==============================] - 7s 3ms/step - loss: 28749.9824
# Epoch 6/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 97647.6641
# Epoch 7/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 23125.5664
# Epoch 8/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 47468.6250
# Epoch 9/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 24347.4355
# Epoch 10/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 115891.7031
# Epoch 11/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 25956.8633
# Epoch 12/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 22719.9199
# Epoch 13/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 31235.1289
# Epoch 14/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 22744.1523
# Epoch 15/100
# 2192/2192 [==============================] - 8s 3ms/step - loss: 22682.0352
# Epoch 16/100
# 2192/2192 [==============================] - 8s 4ms/step - loss: 22418.8848
# Epoch 17/100
# 2192/2192 [==============================] - 8s 3ms/step - loss: 30604.4102
# Epoch 18/100
# 2192/2192 [==============================] - 7s 3ms/step - loss: 25874.8574
# Epoch 19/100
# 2192/2192 [==============================] - 8s 3ms/step - loss: 46934.1758
# Epoch 20/100
#  635/2192 [=======>......................] - ETA: 5s - loss: 46842.9531
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [109], in <cell line: 1>()
# ----> 1 nn.fit(X,Y,epochs=100)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
