# %% [markdown]
# # GBP/USD

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from statsmodels) (1.23.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from statsmodels) (1.4.3)
# Requirement already satisfied: scipy>=1.3 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from statsmodels) (1.9.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\slmss\.conda\envs\forecasting\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from alpha_vantage.foreignexchange import ForeignExchange
import time
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

api_key = 'G7JR90VGP0K0Z50W'
fx = ForeignExchange(key=api_key, output_format='pandas')
data, meta_data = fx.get_currency_exchange_intraday('GBP','USD','1min', 'COMPACT')
data.columns=['o','h','l','c']
data['change']=data.c.pct_change()
df1=data.dropna()
data['c'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # EUR/USD

# %%
data, meta_data = fx.get_currency_exchange_intraday('EUR','USD','1min', 'COMPACT')
# data['4. close'].plot()
data.columns=['o','h','l','c']
data['change']=data.c.pct_change()
df1=data.dropna()

EUR_USD = stats.norm.interval(0.95,
loc = df1.change.mean(),
scale = df1.change.std())

L['EUR_USD']=EUR_USD

# %%
# plt.hist(df1.change)
# plt.show()

# %% [markdown]
# # USD/JPY

# %%
data, meta_data = fx.get_currency_exchange_intraday('USD','JPY','1min', 'COMPACT')
# data['4. close'].plot()
data.columns=['o','h','l','c']
data['change']=data.c.pct_change()
df1=data.dropna()

USD_JPY = stats.norm.interval(0.95,
loc = df1.change.mean(),
scale = df1.change.std())

L['USD_JPY']=USD_JPY

# %% [markdown]
# # USD/CHF

# %%
api_key = '0Q6J2ZR2ZVOLQ65Q'
data, meta_data = fx.get_currency_exchange_intraday('USD','CHF','1min', 'COMPACT')
# data['4. close'].plot()
data.columns=['o','h','l','c']
data['change']=data.c.pct_change()
df1=data.dropna()

USD_CHF = stats.norm.interval(0.95,
loc = df1.change.mean(),
scale = df1.change.std())

L['USD_CHF']=USD_CHF

# %% [markdown]
# # AUD/USD

# %%
api_key = '0Q6J2ZR2ZVOLQ65Q'

# %%
api_key = '0Q6J2ZR2ZVOLQ65Q'
fx = ForeignExchange(key=api_key, output_format='pandas')
data, meta_data = fx.get_currency_exchange_intraday('AUD','USD','1min', 'COMPACT')
# data['4. close'].plot()
data.columns=['o','h','l','c']
data['change']=data.c.pct_change()
df1=data.dropna()

AUS_USD = stats.norm.interval(0.95,
loc = df1.change.mean(),
scale = df1.change.std())

L['AUS_USD']=AUS_USD

# %% [markdown]
# # USD/CAD

# %%
api_key = 'YWB2DP0PPV00JMRS'

fx = ForeignExchange(key=api_key, output_format='pandas')
data, meta_data = fx.get_currency_exchange_intraday('USD','CAD','1min', 'COMPACT')
# data['4. close'].plot()
data.columns=['o','h','l','c']
data['change']=data.c.pct_change()
df1=data.dropna()

USD_CAD = stats.norm.interval(0.95,
loc = df1.change.mean(),
scale = df1.change.std())

L['USD_CAD']=USD_CAD

# %% [markdown]
# # NZD/USD

# %%
data, meta_data = fx.get_currency_exchange_intraday('NZD','USD','1min', 'COMPACT')
# data['4. close'].plot()
data.columns=['o','h','l','c']
data['change']=data.c.pct_change()
df1=data.dropna()

NZD_USD = stats.norm.interval(0.95,
loc = df1.change.mean(),
scale = df1.change.std())

L['NZD_USD']=NZD_USD

# %%
L
