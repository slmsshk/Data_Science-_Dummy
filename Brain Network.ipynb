# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"\Users\Slmss\Documents\GitHub\DataSet\brain_networks.csv",header=None).dropna()

# %%
df.head()
# Out:
#         0                  1                  2                   3   \
# 0  network                  1                  1                   2
# 1     node                  1                  1                   1
# 2     hemi                 lh                 rh                  lh
# 4        0  56.05574417114258  92.03103637695312   3.391575574874878
# 5        1   55.5472526550293   43.6900749206543  -65.49598693847656
#
#                     4                   5                   6   \
# 0                    2                   3                   3
# 1                    1                   1                   1
# 2                   rh                  lh                  rh
# 4    38.65968322753906  26.203819274902344  -49.71556854248047
# 5  -13.974522590637207  -28.27496337890625  -39.05012893676758
#
#                     7                    8                    9   ...  \
# 0                    4                    4                    5  ...
# ...

# %%
df1=df.drop(0,axis=1)
df1.head()
# Out:
#                   1                  2                   3   \
# 0                  1                  1                   2
# 1                  1                  1                   1
# 2                 lh                 rh                  lh
# 4  56.05574417114258  92.03103637695312   3.391575574874878
# 5   55.5472526550293   43.6900749206543  -65.49598693847656
#
#                     4                   5                   6   \
# 0                    2                   3                   3
# 1                    1                   1                   1
# 2                   rh                  lh                  rh
# 4    38.65968322753906  26.203819274902344  -49.71556854248047
# 5  -13.974522590637207  -28.27496337890625  -39.05012893676758
#
#                     7                    8                    9   \
# 0                    4                    4                    5
# 1                    1                    1                    1
# ...

# %%
from sklearn.preprocessing import StandardScaler ,LabelEncoder

# %%
sc=StandardScaler()
le=LabelEncoder()

# %%
df1.iloc[2,:]=le.fit_transform(df1.iloc[2,:])
df1.head()
# Out:
#                   1                  2                   3   \
# 0                  1                  1                   2
# 1                  1                  1                   1
# 2                  0                  1                   0
# 4  56.05574417114258  92.03103637695312   3.391575574874878
# 5   55.5472526550293   43.6900749206543  -65.49598693847656
#
#                     4                   5                   6   \
# 0                    2                   3                   3
# 1                    1                   1                   1
# 2                    1                   0                   1
# 4    38.65968322753906  26.203819274902344  -49.71556854248047
# 5  -13.974522590637207  -28.27496337890625  -39.05012893676758
#
#                     7                    8                    9   \
# 0                    4                    4                    5
# 1                    1                    1                    1
# ...

# %%
df2=df1.copy()
df2.iloc[:,:]=sc.fit_transform(df1)
df2.head()
# Out:
#          1         2         3         4         5         6         7   \
# 0  0.020738  0.019171  0.050696  0.046608  0.115367  0.090883  0.141697
# 1  0.020738  0.019171  0.025235   0.02301  0.038312  0.030066  0.035154
# 2  0.000246  0.019171 -0.000227   0.02301 -0.000216  0.030066  -0.00036
# 4  1.148923  1.727911  0.086128  0.911722   1.00935 -1.512128  1.685179
# 5  1.138503  0.820504  -1.66786 -0.330366 -1.089577 -1.187806 -0.043355
#
#          8         9         10  ...        53        54        55        56  \
# 0  0.139492  0.144162  0.128824  ...   0.30129  0.273968  0.380016  0.557699
# 1  0.034358  0.028734  0.025896  ...  0.055114  0.067505  0.094844  0.032411
# 2  0.034358 -0.000123  0.025896  ...  0.017241 -0.001316  0.023551  -0.00042
# 4  0.936637  -1.03606 -0.048449  ...  0.009816 -1.210335  1.838332 -0.713977
# 5 -0.666985  0.564552   0.40938  ...  1.087067 -1.315677  3.024066 -0.428392
#
#          57        58        59        60        61        62
# ...

# %%
from sklearn.manifold import TSNE

# %%
tsne=TSNE()

# %%
score=pd.DataFrame(tsne.fit_transform(df2),columns=['A','B'])

# %%
plt.figure(figsize=(15,5))
plt.scatter(score.A,score.B)
# plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans
plt.figure(figsize=(25,20))

l=[2,17,4]
n=['hemisphere','Network','Node']
c=1
for i in l:
    k=KMeans(i)
    plt.subplot(3,1,c)
    scatter=plt.scatter(score.A,score.B,c=k.fit_predict(df2))
    legend1 = plt.legend(*scatter.legend_elements(),
                    loc="lower left", title=n[c-1])
    plt.title(n[c-1])
    c+=1
# plt.legend()
# plt.show()

# %%
df1.head()
# Out:
#                   1                  2                   3   \
# 0                  1                  1                   2
# 1                  1                  1                   1
# 2                  0                  1                   0
# 4  56.05574417114258  92.03103637695312   3.391575574874878
# 5   55.5472526550293   43.6900749206543  -65.49598693847656
#
#                     4                   5                   6   \
# 0                    2                   3                   3
# 1                    1                   1                   1
# 2                    1                   0                   1
# 4    38.65968322753906  26.203819274902344  -49.71556854248047
# 5  -13.974522590637207  -28.27496337890625  -39.05012893676758
#
#                     7                    8                    9   \
# 0                    4                    4                    5
# 1                    1                    1                    1
# ...

# %%
df.head()
# Out:
#         0                  1                  2                   3   \
# 0  network                  1                  1                   2
# 1     node                  1                  1                   1
# 2     hemi                 lh                 rh                  lh
# 4        0  56.05574417114258  92.03103637695312   3.391575574874878
# 5        1   55.5472526550293   43.6900749206543  -65.49598693847656
#
#                     4                   5                   6   \
# 0                    2                   3                   3
# 1                    1                   1                   1
# 2                   rh                  lh                  rh
# 4    38.65968322753906  26.203819274902344  -49.71556854248047
# 5  -13.974522590637207  -28.27496337890625  -39.05012893676758
#
#                     7                    8                    9   ...  \
# 0                    4                    4                    5  ...
# ...

# %%
df_network=df.T
df_network.columns=df.T.loc[0]

# %%
dfn=df_network.drop(0,axis=0)
dfn['network']=dfn['network'].astype(int)
dfn1=dfn.sort_values(by='network').reset_index()

# %%
dfn.head()
# Out:
# 0  network node hemi                   0                    1  \
# 1        1    1   lh   56.05574417114258     55.5472526550293
# 2        1    1   rh   92.03103637695312     43.6900749206543
# 3        2    1   lh   3.391575574874878   -65.49598693847656
# 4        2    1   rh   38.65968322753906  -13.974522590637207
# 5        3    1   lh  26.203819274902344   -28.27496337890625
#
# 0                    2                    3                    4  \
# 1    60.99776840209961   18.514867782592773  -2.5273923873901367
# 2    63.43879318237305    12.65715789794922   -63.10466766357422
# 3   -51.10858154296875  -34.576602935791016    -13.8141508102417
# 4  -13.561346054077148  -32.665958404541016   -15.83798885345459
# 5  -18.842947006225586   -7.420454025268555   -45.21692657470703
#
# 0                    5                    6  ...                  910  \
# 1   -24.90679168701172   17.273710250854492  ...    24.22268867492676
# ...

# %%
plt.figure(figsize=(20,30))

for i in range(len(dfn.network.value_counts())):
    tsne=TSNE()
    x=dfn[dfn.network==i+1]
    score=pd.DataFrame(tsne.fit_transform(x.drop(['network','node','hemi'],axis=1).T),columns=['a','b'])
    plt.subplot(6,3,i+1)
    plt.scatter(score.a,score.b,label='network '+ str(i),alpha=0.5)
    plt.legend()

# %%
plt.figure(figsize=(10,10))

for i in range(len(dfn.node.value_counts())):
    tsne=TSNE()
    x=dfn[dfn.node==str(i+1)]
    score=pd.DataFrame(tsne.fit_transform(x.drop(['network','node','hemi'],axis=1).T),columns=['a','b'])
    plt.subplot(2,2,i+1)
    plt.scatter(score.a,score.b,label='Node '+ str(i+1),alpha=0.5)
    plt.legend()

# %%
u=dfn.hemi.unique()
dfn.hemi=le.fit_transform(dfn.hemi)

plt.figure(figsize=(15,5))
for i in range(len(dfn.hemi.value_counts())):
    tsne=TSNE()
    x=dfn[dfn.hemi==i]
    score=pd.DataFrame(tsne.fit_transform(x.drop(['network','node','hemi'],axis=1).T),columns=['a','b'])
    plt.subplot(1,3,i+1)
    plt.scatter(score.a,score.b,label='Hemisphere '+ u[i],alpha=0.8)
    plt.legend()
