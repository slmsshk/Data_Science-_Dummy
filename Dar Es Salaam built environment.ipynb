# %%
# pip install geopandas
# !pip install pyrosm
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 5.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [329 lines of output]
# ...
#        ---------------------------------------- 1.2/1.2 MB 1.6 MB/s eta 0:00:00
# ...
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# ...
#     Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# ...
#        ---------------------------------------- 43.3/43.3 kB ? eta 0:00:00
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
#     Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
import pandas
import geopandas
import pyrosm
import contextily
import h3
import matplotlib.pyplot as plt
from momepy import Linearity
from shapely.geometry import box, Polygon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       2 import geopandas
#       3 import pyrosm
# ----> 4 import contextily
#       5 import h3
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'contextily'

# %%
gdf = geopandas.read_file('https://extract.bbbike.org/?sw_lng=39.199&sw_lat=-6.86&ne_lng=39.409&ne_lat=-6.73&format=osm.pbf&city=Dar+Es+Salaam+Centre&lang=en')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 gdf = geopandas.read_file('https://extract.bbbike.org/?sw_lng=39.199&sw_lat=-6.86&ne_lng=39.409&ne_lat=-6.73&format=osm.pbf&city=Dar+Es+Salaam+Centre&lang=en')
#
# NameError: name 'geopandas' is not defined

# %%
geopandas.datasets
