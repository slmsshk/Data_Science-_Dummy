# %% [markdown]
# <a href="https://colab.research.google.com/github/slmsshk/Data_Science-_Dummy/blob/main/Matplotlib_subplot%2CSkewness%2C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('/content/sample_data/california_housing_test.csv')
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
cordinates=data['latitude'],data['longitude']
type(cordinates)
# Out:
# tuple

# %%
help(data.iloc)

# %%
x=pd.DataFrame(cordinates).T

# %%
x.sort_values('latitude')
# Out:
#       latitude  longitude
# 1208     32.56    -117.09
# 2371     32.57    -117.08
# 1617     32.57    -117.12
# 1045     32.57    -117.11
# 274      32.58    -117.05
# ...        ...        ...
# 2018     41.31    -122.32
# 2778     41.54    -123.92
# 2951     41.63    -122.64
# 1422     41.80    -124.17
# 910      41.92    -124.16
#
# [3000 rows x 2 columns]

# %%
# Histogram
plt.hist(data['households'])
plt.savefig('hist.pdf')
plt.title("histogram")
plt.xlabel("Groups/Bins")
plt.ylabel('Frequency')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')

# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')

# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

# Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)

# Create figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax = plt.subplots(num=10, clear=True)

# %%
#  Generate subplot
plt.figure(figsize=(15,15))
plt.suptitle("Data Distribution", fontsize=15,color='blue')
plt.subplots_adjust(hspace=.5, top=0.94)
fg_color = 'Red'
bg_color = 'pink'

for i,j in enumerate(data.columns):
  plt.subplot(3,3,i+1,facecolor='black')
  plt.title(j,color='green')
  plt.hist(data[j])
  plt.xlabel("Value",color='r') 
  plt.ylabel("Frequency",color='r')
plt.savefig('Distribution.pdf')
  # plt.show() 
  # plt.tight_layout()

# %%
fig = plt.figure()

# Needed to add spacing between 1st and 2nd row
# Add a margin between the main title and sub-plots
fig.subplots_adjust(hspace=0.4, top=0.85)

# Add the main title
fig.suptitle("Main Title", fontsize=15)

# Add the subplots
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# Add the text for each subplot
ax1.title.set_text("First")
ax1.hist(data['longitude'])
ax2.title.set_text("Second")
ax3.title.set_text("Third")
ax4.title.set_text("Fourth")
plt.show()

# %%
help(pd.plotting.scatter_matrix)

# %%
data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925017           -0.064203     0.049865
# latitude            -0.925017  1.000000           -0.025143    -0.039632
# housing_median_age  -0.064203 -0.025143            1.000000    -0.367850
# total_rooms          0.049865 -0.039632           -0.367850     1.000000
# total_bedrooms       0.070869 -0.068245           -0.323154     0.937749
# population           0.111572 -0.117318           -0.299888     0.838867
# households           0.051062 -0.068296           -0.305171     0.914116
# median_income       -0.018701 -0.072363           -0.144315     0.221249
# median_house_value  -0.050662 -0.138428            0.091409     0.160427
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070869    0.111572    0.051062      -0.018701
# latitude                 -0.068245   -0.117318   -0.068296      -0.072363
# ...

# %%
pd.plotting.scatter_matrix(data,figsize=(13,13),alpha=0.2)

# %%
plt.bar(data['population'],data['households'],width=5)
# Out:
# <BarContainer object of 3000 artists>

# %%
#  Generate subplot
plt.figure(figsize=(8,8))
for i,j in enumerate(data.columns):
  
  plt.subplot(3,3,i+1)
  plt.bar(data[j],5)
  plt.title(j)
  plt.tight_layout()

# %%
import matplotlib.pyplot as plt

# define subplots with subplot size
fig, ax = plt.subplots(2, 2, figsize=(8,6))

# # define data
x = [0, 1, 2, 3, 4, 5]
y = [i**2 for i in x]

# create subplots
ax[0, 0].plot(x, y, color='black')
ax[0, 1].plot(x, y, color='green')
ax[1, 0].plot(x, y, color='red')
ax[1, 1].plot(x, y, color='blue')

# display the plot
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=3)

# %%
axes.shape
# Out:
# (3, 3)

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
fdata=data.drop(columns=['latitude','longitude'])

# %%
data.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
help(data.drop)

# %%
fdata
# Out:
#       housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                   27.0       3885.0           661.0      1537.0       606.0
# 1                   43.0       1510.0           310.0       809.0       277.0
# 2                   27.0       3589.0           507.0      1484.0       495.0
# 3                   28.0         67.0            15.0        49.0        11.0
# 4                   19.0       1241.0           244.0       850.0       237.0
# ...                  ...          ...             ...         ...         ...
# 2995                23.0       1450.0           642.0      1258.0       607.0
# 2996                27.0       5257.0          1082.0      3496.0      1036.0
# 2997                10.0        956.0           201.0       693.0       220.0
# 2998                40.0         96.0            14.0        46.0        14.0
# 2999                42.0       1765.0           263.0       753.0       260.0
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
fdata=pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
for i,j in enumerate(fdata.columns):
  print(j)
  print(fdata[j].skew())
  for x in range(2):
    print('-----------------')
# Out:
# longitude
# -0.29785763262779996
# -----------------
# -----------------
# latitude
# 0.45981593679052085
# -----------------
# -----------------
# housing_median_age
# 0.018513121159991593
# -----------------
# -----------------
# total_rooms
# 4.167637358501556
# -----------------
# -----------------
# total_bedrooms
# 3.8633931890458686
# -----------------
# -----------------
# population
# 2.9496706908288868
# -----------------
# -----------------
# households
# 3.5597534116462914
# -----------------
# -----------------
# median_income
# 1.6985117348319874
# -----------------
# -----------------
# median_house_value
# 0.9895619132015638
# -----------------
# -----------------

# %%
for i,j in enumerate(fdata.columns):
  print(j)
  print(fdata[j].kurt())
  for x in range(2):
    print('-----------------')
# Out:
# housing_median_age
# -0.8037837284188449
# -----------------
# -----------------
# total_rooms
# 32.09994094352687
# -----------------
# -----------------
# total_bedrooms
# 28.53707082052359
# -----------------
# -----------------
# population
# 16.443268177004413
# -----------------
# -----------------
# households
# 26.22936134813419
# -----------------
# -----------------
# median_income
# 5.626184148981826
# -----------------
# -----------------
# median_house_value
# 0.39539899642985343
# -----------------
# -----------------

# %%
x=np.log(fdata['households'])
x
# Out:
# 0       6.406880
# 1       5.624018
# 2       6.204558
# 3       2.397895
# 4       5.468060
#           ...
# 2995    6.408529
# 2996    6.943122
# 2997    5.393628
# 2998    2.639057
# 2999    5.560682
# Name: households, Length: 3000, dtype: float64

# %%
x.skew()
# Out:
# -1.3819954365787053

# %%
x=np.sqrt(fdata['households'])
x.skew()
# Out:
# 1.0025936558064152

# %%
from scipy import stats
x=stats.boxcox(fdata['households'])[0]
pd.Series(x).skew()
# Out:
# 0.13671603356733808

# %%
x
# Out:
# array([18.63319137, 14.15205   , 17.37601532, ..., 13.01551966,
#         3.96256483, 13.8320125 ])

# %%
fdata['households']=x

# %%
fdata['households']
# Out:
# 0       18.633191
# 1       14.152050
# 2       17.376015
# 3        3.462261
# 4       13.374440
#           ...
# 2995    18.643742
# 2996    22.344658
# 2997    13.015520
# 2998     3.962565
# 2999    13.832012
# Name: households, Length: 3000, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data['longitude'], y=data['latitude'])
plt.show()
