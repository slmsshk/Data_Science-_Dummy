# %%
#import libarary

import pandas as pd 
import numpy as np
import matplotlib.pyplot as pltfrom 
from sklearn.linear_model import LinearRegression

# %%
#read csv file
ComputerData = pd.read_csv("https://raw.githubusercontent.com/slmsshk/DataSet/main/Computers.csv")

# %%
ComputerData.head(15)
# Out:
#     Unnamed: 0  price  speed   hd  ram  screen   cd multi premium  ads  trend
# 0            1   1499     25   80    4      14   no    no     yes   94      1
# 1            2   1795     33   85    2      14   no    no     yes   94      1
# 2            3   1595     25  170    4      15   no    no     yes   94      1
# 3            4   1849     25  170    8      14   no    no      no   94      1
# 4            5   3295     33  340   16      14   no    no     yes   94      1
# 5            6   3695     66  340   16      14   no    no     yes   94      1
# 6            7   1720     25  170    4      14  yes    no     yes   94      1
# 7            8   1995     50   85    2      14   no    no     yes   94      1
# 8            9   2225     50  210    8      14   no    no     yes   94      1
# 9           10   2575     50  210    4      15   no    no     yes   94      1
# 10          11   2195     33  170    8      15   no    no     yes   94      1
# 11          12   2605     66  210    8      14   no    no     yes   94      1
# 12          13   2045     50  130    4      14   no    no     yes   94      1
# 13          14   2295     25  245    8      14   no    no     yes   94      1
# 14          15   2699     50  212    8      14   no    no     yes   94      1

# %%
#remove columan using columan name
ComputerData.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
ComputerData.head(15)
# Out:
#     price  speed   hd  ram  screen   cd multi premium  ads  trend
# 0    1499     25   80    4      14   no    no     yes   94      1
# 1    1795     33   85    2      14   no    no     yes   94      1
# 2    1595     25  170    4      15   no    no     yes   94      1
# 3    1849     25  170    8      14   no    no      no   94      1
# 4    3295     33  340   16      14   no    no     yes   94      1
# 5    3695     66  340   16      14   no    no     yes   94      1
# 6    1720     25  170    4      14  yes    no     yes   94      1
# 7    1995     50   85    2      14   no    no     yes   94      1
# 8    2225     50  210    8      14   no    no     yes   94      1
# 9    2575     50  210    4      15   no    no     yes   94      1
# 10   2195     33  170    8      15   no    no     yes   94      1
# 11   2605     66  210    8      14   no    no     yes   94      1
# 12   2045     50  130    4      14   no    no     yes   94      1
# 13   2295     25  245    8      14   no    no     yes   94      1
# 14   2699     50  212    8      14   no    no     yes   94      1

# %%
#Find Correlaton
corr = ComputerData.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_989eb_row0_col0, #T_989eb_row1_col1, #T_989eb_row2_col2, #T_989eb_row3_col3, #T_989eb_row4_col4, #T_989eb_row5_col5, #T_989eb_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_989eb_row0_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_989eb_row0_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_989eb_row0_col3, #T_989eb_row2_col6, #T_989eb_row6_col2 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_989eb_row0_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_989eb_row0_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_989eb_row0_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_989eb_row1_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_989eb_row1_col2, #T_989eb_row2_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_989eb_row1_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_989eb_row1_col4, #T_989eb_row6_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_989eb_row1_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_989eb_row1_col6 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_989eb_row2_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_989eb_row2_col3 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_989eb_row2_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_989eb_row2_col5, #T_989eb_row5_col1, #T_989eb_row5_col2, #T_989eb_row5_col3, #T_989eb_row5_col4, #T_989eb_row5_col6, #T_989eb_row6_col0, #T_989eb_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_989eb_row3_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_989eb_row3_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_989eb_row3_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_989eb_row3_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_989eb_row3_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_989eb_row3_col6 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_989eb_row4_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_989eb_row4_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_989eb_row4_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_989eb_row4_col3 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_989eb_row4_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_989eb_row4_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_989eb_row5_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_989eb_row6_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_989eb_row6_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# </style>
# <table id="T_989eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_989eb_level0_col0" class="col_heading level0 col0" >price</th>
#       <th id="T_989eb_level0_col1" class="col_heading level0 col1" >speed</th>
#       <th id="T_989eb_level0_col2" class="col_heading level0 col2" >hd</th>
#       <th id="T_989eb_level0_col3" class="col_heading level0 col3" >ram</th>
#       <th id="T_989eb_level0_col4" class="col_heading level0 col4" >screen</th>
#       <th id="T_989eb_level0_col5" class="col_heading level0 col5" >ads</th>
#       <th id="T_989eb_level0_col6" class="col_heading level0 col6" >trend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_989eb_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_989eb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_989eb_row0_col1" class="data row0 col1" >0.300976</td>
#       <td id="T_989eb_row0_col2" class="data row0 col2" >0.430258</td>
#       <td id="T_989eb_row0_col3" class="data row0 col3" >0.622748</td>
#       <td id="T_989eb_row0_col4" class="data row0 col4" >0.296041</td>
#       <td id="T_989eb_row0_col5" class="data row0 col5" >0.054540</td>
#       <td id="T_989eb_row0_col6" class="data row0 col6" >-0.199987</td>
#     </tr>
#     <tr>
#       <th id="T_989eb_level0_row1" class="row_heading level0 row1" >speed</th>
#       <td id="T_989eb_row1_col0" class="data row1 col0" >0.300976</td>
#       <td id="T_989eb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_989eb_row1_col2" class="data row1 col2" >0.372304</td>
#       <td id="T_989eb_row1_col3" class="data row1 col3" >0.234760</td>
#       <td id="T_989eb_row1_col4" class="data row1 col4" >0.189074</td>
#       <td id="T_989eb_row1_col5" class="data row1 col5" >-0.215232</td>
#       <td id="T_989eb_row1_col6" class="data row1 col6" >0.405438</td>
#     </tr>
#     <tr>
#       <th id="T_989eb_level0_row2" class="row_heading level0 row2" >hd</th>
#       <td id="T_989eb_row2_col0" class="data row2 col0" >0.430258</td>
#       <td id="T_989eb_row2_col1" class="data row2 col1" >0.372304</td>
#       <td id="T_989eb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_989eb_row2_col3" class="data row2 col3" >0.777726</td>
#       <td id="T_989eb_row2_col4" class="data row2 col4" >0.232802</td>
#       <td id="T_989eb_row2_col5" class="data row2 col5" >-0.323222</td>
#       <td id="T_989eb_row2_col6" class="data row2 col6" >0.577790</td>
#     </tr>
#     <tr>
#       <th id="T_989eb_level0_row3" class="row_heading level0 row3" >ram</th>
#       <td id="T_989eb_row3_col0" class="data row3 col0" >0.622748</td>
#       <td id="T_989eb_row3_col1" class="data row3 col1" >0.234760</td>
#       <td id="T_989eb_row3_col2" class="data row3 col2" >0.777726</td>
#       <td id="T_989eb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_989eb_row3_col4" class="data row3 col4" >0.208954</td>
#       <td id="T_989eb_row3_col5" class="data row3 col5" >-0.181670</td>
#       <td id="T_989eb_row3_col6" class="data row3 col6" >0.276844</td>
#     </tr>
#     <tr>
#       <th id="T_989eb_level0_row4" class="row_heading level0 row4" >screen</th>
#       <td id="T_989eb_row4_col0" class="data row4 col0" >0.296041</td>
#       <td id="T_989eb_row4_col1" class="data row4 col1" >0.189074</td>
#       <td id="T_989eb_row4_col2" class="data row4 col2" >0.232802</td>
#       <td id="T_989eb_row4_col3" class="data row4 col3" >0.208954</td>
#       <td id="T_989eb_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_989eb_row4_col5" class="data row4 col5" >-0.093919</td>
#       <td id="T_989eb_row4_col6" class="data row4 col6" >0.188614</td>
#     </tr>
#     <tr>
#       <th id="T_989eb_level0_row5" class="row_heading level0 row5" >ads</th>
#       <td id="T_989eb_row5_col0" class="data row5 col0" >0.054540</td>
#       <td id="T_989eb_row5_col1" class="data row5 col1" >-0.215232</td>
#       <td id="T_989eb_row5_col2" class="data row5 col2" >-0.323222</td>
#       <td id="T_989eb_row5_col3" class="data row5 col3" >-0.181670</td>
#       <td id="T_989eb_row5_col4" class="data row5 col4" >-0.093919</td>
#       <td id="T_989eb_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_989eb_row5_col6" class="data row5 col6" >-0.318553</td>
#     </tr>
#     <tr>
#       <th id="T_989eb_level0_row6" class="row_heading level0 row6" >trend</th>
#       <td id="T_989eb_row6_col0" class="data row6 col0" >-0.199987</td>
#       <td id="T_989eb_row6_col1" class="data row6 col1" >0.405438</td>
#       <td id="T_989eb_row6_col2" class="data row6 col2" >0.577790</td>
#       <td id="T_989eb_row6_col3" class="data row6 col3" >0.276844</td>
#       <td id="T_989eb_row6_col4" class="data row6 col4" >0.188614</td>
#       <td id="T_989eb_row6_col5" class="data row6 col5" >-0.318553</td>
#       <td id="T_989eb_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
ComputerData.describe()
# Out:
#              price        speed           hd          ram       screen  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   2219.576610    52.011024   416.601694     8.286947    14.608723
# std     580.803956    21.157735   258.548445     5.631099     0.905115
# min     949.000000    25.000000    80.000000     2.000000    14.000000
# 25%    1794.000000    33.000000   214.000000     4.000000    14.000000
# 50%    2144.000000    50.000000   340.000000     8.000000    14.000000
# 75%    2595.000000    66.000000   528.000000     8.000000    15.000000
# max    5399.000000   100.000000  2100.000000    32.000000    17.000000
#
#                ads        trend
# count  6259.000000  6259.000000
# mean    221.301007    15.926985
# std      74.835284     7.873984
# min      39.000000     1.000000
# 25%     162.500000    10.000000
# 50%     246.000000    16.000000
# 75%     275.000000    21.500000
# max     339.000000    35.000000

# %%
#split data using columan name
x = pd.DataFrame(ComputerData, columns = ['speed', 'hd', 'ram', 'screen', 'ads', 'trend'])

# %%
x
# Out:
#       speed    hd  ram  screen  ads  trend
# 0        25    80    4      14   94      1
# 1        33    85    2      14   94      1
# 2        25   170    4      15   94      1
# 3        25   170    8      14   94      1
# 4        33   340   16      14   94      1
# ...     ...   ...  ...     ...  ...    ...
# 6254    100   528    8      15   39     35
# 6255     66   850   16      15   39     35
# 6256    100  1200   24      15   39     35
# 6257    100   850   16      15   39     35
# 6258    100   850   16      17   39     35
#
# [6259 rows x 6 columns]

# %%
y = pd.DataFrame(ComputerData, columns = ['price'])
y
# Out:
#       price
# 0      1499
# 1      1795
# 2      1595
# 3      1849
# 4      3295
# ...     ...
# 6254   1690
# 6255   2223
# 6256   2654
# 6257   2195
# 6258   2490
#
# [6259 rows x 1 columns]

# %%
# Scatter plot between the variables along with histograms

import seaborn as sns
sns.pairplot(ComputerData)

# %%
# Preparing model                  
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
#check score
reg.score(x,y)
# Out:
# 0.7123057091817093
